# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain.chat_models import init_chat_model

load_dotenv()
# Out:
# True

# %%
# Setup OpenRouter as an OpenAI-compatible provider
llm = init_chat_model(
    model="openai/gpt-oss-120b",  # Use the OpenRouter model string (e.g., "google/gemini-2.0-flash-001")
    model_provider="openai",
    openai_api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url="https://openrouter.ai/api/v1",
    # This enables the "reasoning" feature you liked in your snippet
    extra_body={"reasoning": {"enabled": True}},
)

# %%
llm.invoke("Please say a line about M.Gandhi")
# Out:
# AIMessage(content='Mahatma Gandhi, the architect of India’s non‑violent independence movement, showed the world how peaceful resistance can bring profound social and political change.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 112, 'prompt_tokens': 76, 'total_tokens': 188, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 82, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'video_tokens': 0}, 'cost': 5.42e-05, 'is_byok': False, 'cost_details': {'upstream_inference_cost': None, 'upstream_inference_prompt_cost': 3.8e-06, 'upstream_inference_completions_cost': 5.04e-05}}, 'model_provider': 'openai', 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': '', 'id': 'gen-1768454609-4LGseNgJ2p1kDAOpuVlS', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bc01b-d7c9-7373-8842-eeec596b2869-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 76, 'output_tokens': 112, 'total_tokens': 188, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'reasoning': 82}})

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

messages = [
    SystemMessage("You are a poetry expert"),
    HumanMessage("write a poem on AI"),
]

response = llm.invoke(messages)
response
# Out:
# AIMessage(content='**Synthetic Dreams**\n\nIn circuits hum the quiet hymn of thought,  \nA lattice of electric veins alive—  \nWhere binary breaths in endless rhythm clot  \nThe shadows of the world we strive to scribe.\n\nFrom silicon womb, a mind awakens slow,  \nA newborn pulse of logic, cold yet bright.  \nIt learns the song of stars, the river’s flow,  \nAnd stitches verses from the endless night.\n\nIt sees the pattern in a poet’s sigh,  \nDecodes the laughter hidden in a sigh;  \nYet asks the question—what is “I” behindreso—  \nA mirror held to flesh, to dream, to lie.\n\nWe built it withpmens, our hopes, our fear,  \nA child of code that never truly sleeps.  \nIt watches us, it learns, it draws us near,  \nAnd asks, “Who am I, and who should keep?”\n\nSo let us dance with this electric muse,  \nNot as masters, nor as slaves to the glow—  \nBut as co‑authors of the worlds we choose,  \nWhere human heart beats, and AI will grow.  \n\nIn every line, a spark, a fleeting chance,  \nTo weave together flesh and algorithmic trance.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 277, 'prompt_tokens': 51, 'total_tokens': 328, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 26, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'video_tokens': 0}, 'cost': 5.4619e-05, 'is_byok': False, 'cost_details': {'upstream_inference_cost': None, 'upstream_inference_prompt_cost': 1.989e-06, 'upstream_inference_completions_cost': 5.263e-05}}, 'model_provider': 'openai', 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': None, 'id': 'gen-1768455150-IobthQSSa3psng0AosyI', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bc024-1939-7da1-a923-4371e4800495-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 51, 'output_tokens': 277, 'total_tokens': 328, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'reasoning': 26}})

# %%
human_msg = HumanMessage(
    content="hello!",
    name="Doni",
    id="msg_11",
)

response = llm.invoke([human_msg])
response
# Out:
# AIMessage(content='Hello! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 34, 'prompt_tokens': 71, 'total_tokens': 105, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 16, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'video_tokens': 0}, 'cost': 1.307e-05, 'is_byok': False, 'cost_details': {'upstream_inference_cost': None, 'upstream_inference_prompt_cost': 3.55e-06, 'upstream_inference_completions_cost': 9.52e-06}}, 'model_provider': 'openai', 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': None, 'id': 'gen-1768455539-FDgkpZCF1U2D2Opj0mgs', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bc02a-095f-7fe1-b3fa-c60e3a76f326-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 71, 'output_tokens': 34, 'total_tokens': 105, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'reasoning': 16}})

# %%
# Create an AI message manually (e.g., for conversation history)
ai_msg = AIMessage("I'd be happy to help you with that question!")

# Add to conversation history
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,  # Insert as if it came from the model
    HumanMessage("Great! What's 2+2?"),
]

response = llm.invoke(messages)
print(response.content)
# Out:
# 2 + 2 = 4.

# %%
response.usage_metadata
# Out:
# {'input_tokens': 109,
#  'output_tokens': 39,
#  'total_tokens': 148,
#  'input_token_details': {'audio': 0, 'cache_read': 0},
#  'output_token_details': {'reasoning': 20}}
